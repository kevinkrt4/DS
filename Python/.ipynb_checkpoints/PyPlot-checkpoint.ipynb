# %% [markdown]
# # Pyplot Lines

# %% [markdown]
# ## Number of people drowned by falling Into a Pool correlates with movies Nicholas Cage appeared in
#
# www.tylervigen.com/spurious-correlations

# %%
from matplotlib import pyplot as plt

# Initialize variables
years =  [1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007,2008, 2009]
movies =    [2, 2, 2, 3,1, 1, 2, 3, 4, 1, 4]
drownings = [109, 102, 102, 98, 85, 95, 96, 98, 123, 94, 102]

movies_scaling_factor = 10

# Apply scaling
scaled_movies = []
for i in movies:
    scaled_movies.append(i * movies_scaling_factor)
print (scaled_movies)
# Out:
# [20, 20, 20, 30, 10, 10, 20, 30, 40, 10, 40]

# %%
# Show plot table
index = 0
print('Source Data'.center(30))
print('Years'.center(9), 'Movies'.center(9), 'Drownings'.center(9))
while index < len(years):    
    print (repr(years[index]).rjust(9), repr(movies[index]).rjust(9), repr(drownings[index]).rjust(9))
    index += 1
#print(repr(num).center(3))
#print (str(s).center(3))
#print (repr(s))
# Out:
#          Source Data
#   Years     Movies  Drownings
#      1999         2       109
#      2000         2       102
#      2001         2       102
#      2002         3        98
#      2003         1        85
#      2004         1        95
#      2005         2        96
#      2006         3        98
#      2007         4       123
#      2008         1        94
#      2009         4       102

# %% [markdown]
# Table 1: Data values

# %% [markdown]
# ### Plot on a single graph

# %%
# Plot
plt.close('all')
plt.plot(years, scaled_movies)
plt.plot(years, drownings)
plt.title('Cage Movies Versus Drownings')
plt.xlabel('Year')
plt.xlabel('Year')
plt.legend(['movies', 'drownings']) 


# Show plots
plt.show()

# %% [markdown]
# Figure 1 Data Plot
#
# *Used scaling factor to graph movies. See Table 1 for original data listing.*

# %% [markdown]
# ### Use SubPlots

# %%
plt.close('all')
#plt.subplots_adjust(hspace=0.3)

ax_drownings = plt.subplot(2,1,1)
ax_drownings.set_xticks([])
ax_drownings.plot(years, drownings, color='pink', marker='o')
plt.ylabel('Drownings')

ax_movies = plt.subplot(2,1,2)
ax_movies.plot(years, movies, color='grey', marker='o')
plt.xlabel('Years')
plt.ylabel('Movies')

plt.show()

# %% [markdown]
# ### Use Separate Figures

# %%
#plt.close('all')

figs = plt.figure()
plt.plot(years,movies, color='grey')
plt.title('Movies')
plt.xlabel('Years')
plt.ylabel('Movies')
plt.show()
plt.close('all')

fig2 = plt.figure()
plt.plot(years, drownings, color='red')
plt.title("Drownings")
plt.xlabel('Years')
plt.ylabel('Drownings')
plt.show()
plt.close('all')

# %%
# China Data (blue bars)
n = 1  # This is our first dataset (out of 2)
t = 2 # Number of datasets
d = 7 # Number of sets of bars
w = 0.8 # Width of each bar
x_values1 = [t*element + w*n for element
             in range(d)]
print (x_values1)
# Out:
# [0.8, 2.8, 4.8, 6.8, 8.8, 10.8, 12.8]

# %%
# China Data (blue bars)
n = 2  # This is our first dataset (out of 2)
t = 2 # Number of datasets
d = 7 # Number of sets of bars
w = 0.8 # Width of each bar
x_values2 = [t*element + w*n for element
             in range(d)]

print (x_values2)
# Out:
# [1.6, 3.6, 5.6, 7.6, 9.6, 11.6, 13.6]

# %% [markdown]
# # PyPlot Functions

# %% [markdown]
# ## Linear
